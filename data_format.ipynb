# %%
import os
import json

# Define paths
input_directory = 'data'  # The directory containing your JSON files
output_file_path = 'combined_questions_with_sections.json'  # The path for the single output JSON file

# Initialize an empty list to collect all questions
all_questions = []
sections_info = {}  # To collect unique section names

# Iterate over each file in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith('.json'):
        input_file_path = os.path.join(input_directory, filename)

        # Open and load the JSON data
        with open(input_file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
        
        # Extract section name from the JSON file itself
        section_name = data.get('section_name', 'Unknown Section')

        # Modify each question to include the section name
        for question in data.get('questions', []):
            question['section_name'] = section_name
            
            # If the section_name is new, add it to sections_info
            if section_name not in sections_info:
                sections_info[section_name] = {
                    "name": section_name,
                    "description": f"Questions from the section {section_name}."
                }
            
            # Append the question to the global all_questions list
            all_questions.append(question)

        print(f"Processed: {filename}")

# Create a list of sections from the sections_info
sections_list = [
    {
        "name": section["name"], 
        "description": section["description"]
    }
    for section in sections_info.values()
]

# Save the combined data to a single output file with "sections" and "questions"
output_data = {
    "sections": sections_list,
    "questions": all_questions
}

with open(output_file_path, 'w', encoding='utf-8') as output_file:
    json.dump(output_data, output_file, indent=4)

print(f"All sections and questions combined and saved to {output_file_path}")
# Out:
# Processed: abraham's_faith_and_promise.json
# Processed: abraham's_faith_and_promise_event_sequencing.json
# Processed: adam_and_christ_contrast.json
# Processed: adam_and_christ_contrast_event_sequencing.json
# Processed: all_have_sinned.json
# Processed: all_have_sinned_event_sequencing.json
# Processed: genesis_37 - difficult questions.json
# Processed: genesis_37 Fill in the blank.json
# Processed: genesis_37 Thematic Questions.json
# Processed: genesis_37.json
# Processed: genesis_38 - difficult questions.json
# Processed: genesis_38 Fill in the blank.json
# Processed: genesis_38 Thematic Questions.json
# Processed: genesis_38.json
# Processed: genesis_39 - difficult questions.json
# Processed: genesis_39 Fill in the blank.json
# Processed: genesis_39 Thematic Questions.json
# Processed: genesis_39.json
# Processed: genesis_40 - difficult questions.json
# Processed: genesis_40 Fill in the blank.json
# Processed: genesis_40 Thematic Questions.json
# Processed: genesis_40.json
# Processed: genesis_41 - difficult questions.json
# Processed: genesis_41 Fill in the blank.json
# Processed: genesis_41 Thematic Questions.json
# Processed: genesis_41.json
# Processed: genesis_42 - difficult questions.json
# Processed: genesis_42 Fill in the blank.json
# Processed: genesis_42 Thematic Questions.json
# Processed: genesis_42.json
# Processed: genesis_43 - difficult questions.json
# Processed: genesis_43 Fill in the blank.json
# Processed: genesis_43 Thematic Questions.json
# Processed: genesis_43.json
# Processed: genesis_44 - difficult questions.json
# Processed: genesis_44 Fill in the blank.json
# Processed: genesis_44 Thematic Questions.json
# Processed: genesis_44.json
# Processed: genesis_45 - difficult questions.json
# Processed: genesis_45 Fill in the blank.json
# Processed: genesis_45 Thematic Questions.json
# Processed: genesis_45.json
# Processed: genesis_46 - difficult questions.json
# Processed: genesis_46 Fill in the blank.json
# Processed: genesis_46 Thematic Questions.json
# Processed: genesis_46.json
# Processed: genesis_47 - difficult questions.json
# Processed: genesis_47 Fill in the blank.json
# Processed: genesis_47 Thematic Questions.json
# Processed: genesis_47.json
# Processed: genesis_48 - difficult questions.json
# Processed: genesis_48 Fill in the blank.json
# Processed: genesis_48 Thematic Questions.json
# Processed: genesis_48.json
# Processed: genesis_49 - difficult questions.json
# Processed: genesis_49 Fill in the blank.json
# Processed: genesis_49 Thematic Questions.json
# Processed: genesis_49.json
# Processed: genesis_50 - difficult questions.json
# Processed: genesis_50 Fill in the blank.json
# Processed: genesis_50 Thematic Questions.json
# Processed: genesis_50.json
# Processed: god's_kindness.json
# Processed: god's_kindness_event_sequencing.json
# Processed: god's_providence_and_sovereignty.json
# Processed: god's_providence_and_sovereignty_event_sequencing.json
# Processed: god's_righteous_judgment.json
# Processed: god's_righteous_judgment_event_sequencing.json
# Processed: god's_wrath_and_mercy.json
# Processed: god's_wrath_and_mercy_event_sequencing.json
# Processed: god_and_israel’s_future.json
# Processed: god_and_israel’s_future_event_sequencing.json
# Processed: god’s_faithfulness_to_israel.json
# Processed: god’s_faithfulness_to_israel_event_sequencing.json
# Processed: jacob's_blessings_and_prophecies.json
# Processed: jacob's_blessings_and_prophecies_event_sequencing.json
# Processed: jacob's_last_days_and_blessings.json
# Processed: jacob's_last_days_and_blessings_event_sequencing.json
# Processed: joseph's_dreams_and_interpretations.json
# Processed: joseph's_dreams_and_interpretations_event_sequencing.json
# Processed: joseph's_family_reunion.json
# Processed: joseph's_family_reunion_event_sequencing.json
# Processed: joseph's_forgiveness_and_reconciliation.json
# Processed: joseph's_forgiveness_and_reconciliation_event_sequencing.json
# Processed: joseph's_rise_to_power.json
# Processed: joseph's_rise_to_power_event_sequencing.json
# Processed: joseph's_story.json
# Processed: joseph's_story_event_sequencing.json
# Processed: judah’s_transformation_and_leadership.json
# Processed: judah’s_transformation_and_leadership_event_sequencing.json
# Processed: justification_by_faith.json
# Processed: justification_by_faith_event_sequencing.json
# Processed: life_in_the_spirit.json
# Processed: life_in_the_spirit_event_sequencing.json
# Processed: peace_with_god_through_christ.json
# Processed: peace_with_god_through_christ_event_sequencing.json
# Processed: priestly_and_royal_leadership.json
# Processed: priestly_and_royal_leadership_event_sequencing.json
# Processed: romans_1 - difficult questions.json
# Processed: romans_1 Fill in the blank.json
# Processed: romans_1 Thematic Questions.json
# Processed: romans_1.json
# Processed: romans_10 - difficult questions.json
# Processed: romans_10 Fill in the blank.json
# Processed: romans_10 Thematic Questions.json
# Processed: romans_10.json
# Processed: romans_2 - difficult questions.json
# Processed: romans_2 Fill in the blank.json
# Processed: romans_2 Thematic Questions.json
# Processed: romans_2.json
# Processed: romans_3 - difficult questions.json
# Processed: romans_3 Fill in the blank.json
# Processed: romans_3 Thematic Questions.json
# Processed: romans_3.json
# Processed: romans_4 - difficult questions.json
# Processed: romans_4 Fill in the blank.json
# Processed: romans_4 Thematic Questions.json
# Processed: romans_4.json
# Processed: romans_5 - difficult questions.json
# Processed: romans_5 Fill in the blank.json
# Processed: romans_5 Thematic Questions.json
# Processed: romans_5.json
# Processed: romans_6 - difficult questions.json
# Processed: romans_6 Fill in the blank.json
# Processed: romans_6 Thematic Questions.json
# Processed: romans_6.json
# Processed: romans_7 - difficult questions.json
# Processed: romans_7 Fill in the blank.json
# Processed: romans_7 Thematic Questions.json
# Processed: romans_7.json
# Processed: romans_8 - difficult questions.json
# Processed: romans_8 Fill in the blank.json
# Processed: romans_8 Thematic Questions.json
# Processed: romans_8.json
# Processed: romans_9 - difficult questions.json
# Processed: romans_9 Fill in the blank.json
# Processed: romans_9 Thematic Questions.json
# Processed: romans_9.json
# Processed: struggle_with_sin_and_grace.json
# Processed: struggle_with_sin_and_grace_event_sequencing.json
# Processed: temple_rebuilding_and_restoration.json
# Processed: temple_rebuilding_and_restoration_event_sequencing.json
# Processed: the_role_of_the_law.json
# Processed: the_role_of_the_law_event_sequencing.json
# Processed: union_with_christ.json
# Processed: union_with_christ_event_sequencing.json
# Processed: zechariah's_future_messianic_hope.json
# Processed: zechariah's_future_messianic_hope_event_sequencing.json
# Processed: zechariah's_message_of_repentance.json
# Processed: zechariah's_message_of_repentance_event_sequencing.json
# Processed: zechariah's_visions.json
# Processed: zechariah's_visions_event_sequencing.json
# Processed: zechariah_1 - difficult questions.json
# Processed: zechariah_1 Fill in the blank.json
# Processed: zechariah_1 Thematic Questions.json
# Processed: zechariah_1.json
# Processed: zechariah_2 - difficult questions.json
# Processed: zechariah_2 Fill in the blank.json
# Processed: zechariah_2 Thematic Questions.json
# Processed: zechariah_2.json
# Processed: zechariah_3 - difficult questions.json
# Processed: zechariah_3 Fill in the blank.json
# Processed: zechariah_3 Thematic Questions.json
# Processed: zechariah_3.json
# Processed: zechariah_4 - difficult questions.json
# Processed: zechariah_4 Fill in the blank.json
# Processed: zechariah_4 Thematic Questions.json
# Processed: zechariah_4.json
# Processed: zechariah_5 - difficult questions.json
# Processed: zechariah_5 Fill in the blank.json
# Processed: zechariah_5 Thematic Questions.json
# Processed: zechariah_5.json
# Processed: zechariah_6 - difficult questions.json
# Processed: zechariah_6 Fill in the blank.json
# Processed: zechariah_6 Thematic Questions.json
# Processed: zechariah_6.json
# All sections and questions combined and saved to combined_questions_with_sections.json
